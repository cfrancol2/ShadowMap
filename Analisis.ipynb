# %%
import pandas as pd
ruta3 = "Datos/forum_records.csv"
ruta2 = "Datos/forum_records_clean.csv"
ruta = "Datos/texto_enriquesido.csv"
datos =pd.read_csv(ruta2)
datos.head(5)
# Out:
# C:\Users\impro\AppData\Local\Temp\ipykernel_10660\582633337.py:5: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos =pd.read_csv(ruta2)
#              id_mensaje                          huella_contenido  \
# 0  msg_12c0b467a3be7bba  bafd191c96e38cb5b662ade986ffe80ef95ad4f1
# 1  msg_52bbeb0d3e510422  ea46d956c01fbc325b608a74d2935296a62c9fc2
# 2  msg_cfa5b412d0ad65c8  12f136e7817a80fadc4b5c5a88697f34835d3adc
# 3  msg_d0c9fa35ed564cca  aa8acd9e10bba8a53c6debb61356bb72ed5da018
# 4  msg_180336af506b696d  51db411fb93f33c8804817c0ecf32d5ae28edb41
#
#                    id_hilo         usuario                        fecha_hora  \
# 0  thread_eca162f1d7b4f210          /u/rs7  2026-06-12T01:15:33.280340+00:00
# 1  thread_eca162f1d7b4f210            /u/X  2026-06-12T01:15:33.289347+00:00
# 2  thread_eca162f1d7b4f210    unknown_user  2026-06-12T01:15:33.292179+00:00
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34048 entries, 0 to 34047
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_mensaje           34048 non-null  object
#  1   huella_contenido     34048 non-null  object
#  2   id_hilo              34048 non-null  object
#  3   usuario              34048 non-null  object
#  4   fecha_hora           34048 non-null  object
#  5   fecha                34048 non-null  object
#  6   año                  34048 non-null  int64
#  7   mes                  34048 non-null  int64
#  8   dia                  34048 non-null  int64
#  9   hora                 34048 non-null  int64
#  10  titulo_limpio        34048 non-null  object
#  11  cuerpo_limpio        34048 non-null  object
#  12  texto_citado_limpio  210 non-null    object
#  13  longitud_titulo      34048 non-null  int64
#  14  longitud_cuerpo      34048 non-null  int64
# ...

# %%
datos["id_mensaje"].astype(str)
# Out:
# 0        msg_12c0b467a3be7bba
# 1        msg_52bbeb0d3e510422
# 2        msg_cfa5b412d0ad65c8
# 3        msg_d0c9fa35ed564cca
# 4        msg_180336af506b696d
#                  ...
# 34043    msg_ea1693804af81a07
# 34044    msg_afbc8b59dc5490a1
# 34045    msg_1c5cc7ef6b2f8248
# 34046    msg_3e1ec2131f21ab3d
# 34047    msg_725e338c076a1081
# Name: id_mensaje, Length: 34048, dtype: object

# %%
datos["titulo_limpio"].value_counts()
# Out:
# titulo_limpio
# catalog onion sites                                                                                                    31824
# lockbit blog                                                                                                             980
# posting without captchas or waiting for mod approval is now possible with anonymous tokens  see p218086 for details      362
# dark matter project                                                                                                      208
# affiliate program                                                                                                        172
#                                                                                                                        ...
# buy  store  send crypto coin wallet                                                                                        2
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34048 entries, 0 to 34047
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_mensaje           34048 non-null  object
#  1   huella_contenido     34048 non-null  object
#  2   id_hilo              34048 non-null  object
#  3   usuario              34048 non-null  object
#  4   fecha_hora           34048 non-null  object
#  5   fecha                34048 non-null  object
#  6   año                  34048 non-null  int64
#  7   mes                  34048 non-null  int64
#  8   dia                  34048 non-null  int64
#  9   hora                 34048 non-null  int64
#  10  titulo_limpio        34048 non-null  object
#  11  cuerpo_limpio        34048 non-null  object
#  12  texto_citado_limpio  210 non-null    object
#  13  longitud_titulo      34048 non-null  int64
#  14  longitud_cuerpo      34048 non-null  int64
# ...

# %%
columnas_str = ['id_mensaje', 'huella_contenido', 'id_hilo', 'usuario', 'fecha_hora', 'titulo_limpio', 'cuerpo_limpio',
                    'texto_citado_limpio', 'url_original']
for col in columnas_str:
    if col in datos.columns:
        datos[col] = datos[col].fillna('').astype("string")

# %%
# En pandas, las columnas de texto suelen mostrarse con dtype "object"
# aunque cada valor sea una cadena. Por eso `astype(str)` no cambia la etiqueta
# de dtype a "str" en el resumen de `info()`.
# Si quieres usar el dtype de cadena de pandas, convierte a "string":
datos[columnas_str] = datos[columnas_str].astype("string")
datos[columnas_str].dtypes

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34048 entries, 0 to 34047
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_mensaje           34048 non-null  string
#  1   huella_contenido     34048 non-null  string
#  2   id_hilo              34048 non-null  string
#  3   usuario              34048 non-null  string
#  4   fecha_hora           34048 non-null  string
#  5   fecha                34048 non-null  object
#  6   año                  34048 non-null  int64
#  7   mes                  34048 non-null  int64
#  8   dia                  34048 non-null  int64
#  9   hora                 34048 non-null  int64
#  10  titulo_limpio        34048 non-null  string
#  11  cuerpo_limpio        34048 non-null  string
#  12  texto_citado_limpio  34048 non-null  string
#  13  longitud_titulo      34048 non-null  int64
#  14  longitud_cuerpo      34048 non-null  int64
# ...
